# %%
from tensorflow import keras
import tensorflow
import matplotlib.pyplot as plt
import cv2
import numpy as np

# %%
cv2.setUseOptimized(True)
ss = cv2.ximgproc.segmentation.createSelectiveSearchSegmentation()

# %%
from flask import Flask, render_template, request
#from keras.preprocessing.image import load_img, img_to_array
from tensorflow.keras.utils import load_img, img_to_array
#from tensorflow.keras.applications.vgg16 import preprocess_input, decode_predictions, VGG16

# %%
from werkzeug.wrappers import Request, Response

# %%
app=Flask(__name__)
#model=VGG16()
model=keras.models.load_model('Model.h5', compile=False)

# %%
model.compile(loss='binary_crossentropy',optimizer=tensorflow.keras.optimizers.Adam(),metrics='accuracy')

# %%
@app.route('/',methods=['GET'])
def hello():
    return render_template('index.html')

# %%
@app.route('/',methods=['POST'])
def pred():
    img=request.files['imagefile']
    img_path="images/"+img.filename
    img.save(img_path)
    car=[]
    image=cv2.imread(img_path)
    ss.setBaseImage(image)
    ss.switchToSelectiveSearchFast()
    rects = ss.process()
    for i in rects:
        x, y, w, h = i
        bb={'x1':x,
             'y1':y,
             'x2':x+w,
             'y2':y+h
            }
    img_data=image[bb['y1']:bb['y2'],bb['x1']:bb['x2']]
    img_data=cv2.resize(img_data,(224,224))
    Guess=model.predict(img_data.reshape(1,224,224,3))
    if Guess[0]>0.5:
      car.append([bb,Guess[0]])
    else:
      pass
    test_img=cv2.imread(img_path)
    x=np.argmax(np.array(car)[:,1])
    pt1=(car[x][0]['x1'],car[x][0]['y1'])
    pt2=(car[x][0]['x2'],car[x][0]['y2'])
    #y=np.array(car)
    #pt1=(y[0]["x1"],y[0]["y1"])
    #pt2=(y[0]["x2"],y[0]["y2"])
    plt.figure()
    plt.imshow(test_img)
    cv2.rectangle(test_img,pt1,pt2,(255, 0, 0),2)
    plt.figure()
    classification=car[np.argmax(np.array(car)[:,1])][1][0]*100
    plt.imshow(test_img);
    detectedpath="images/images.png"
    detectedpathjpg="images/images.jpg"
    plt.savefig(detectedpath)
    return render_template('index.html', prediction=classification, detectedimage=detectedpath)

# %%
# #    img=request.files['imagefile']
# img_path="75.jpg"
#  #   img.save(img_path)
# car=[]
# image=cv2.imread(img_path)
# ss.setBaseImage(image)
# ss.switchToSelectiveSearchFast()
# rects = ss.process()
# for i in rects:
#     x, y, w, h = i
#     bb= {'x1':x,
#         'y1':y,
#         'x2':x+w,
#         'y2':y+h
#         }
# img_data=image[bb['y1']:bb['y2'],bb['x1']:bb['x2']]
# img_data=cv2.resize(img_data,(224,224))
# Guess=model.predict(img_data.reshape(1,224,224,3))
# if Guess[0]>0.5:
#     car.append([bb,Guess[0]])
# else:
#     pass
# test_img=cv2.imread(img_path)
# y=np.array(car)[:,1]
# x=np.argmax(y)
# pt1=(car[x][0]['x1'],car[x][0]['y1'])
# pt2=(car[x][0]['x2'],car[x][0]['y2'])
# plt.figure()
# plt.imshow(test_img)
# cv2.rectangle(test_img,pt1,pt2,(255, 0, 0),2)
# plt.figure()
# classification=car[np.argmax(np.array(car)[:,1])][1][0]*100
# plt.imshow(test_img);
# detectedpath="images/images.png"
# detectedpathjpg="images/images.jpg"
# plt.savefig(detectedpath)
# car
# #return render_template('index.html', prediction=classification, detectedimage=detectedpath)
# Out:
# 1/1 [==============================] - 8s 8s/step
# C:\Users\Anil\AppData\Local\Temp\ipykernel_8888\3287580837.py:24: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   y=np.array(car)[:,1]
# C:\Users\Anil\AppData\Local\Temp\ipykernel_8888\3287580837.py:32: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   classification=car[np.argmax(np.array(car)[:,1])][1][0]*100
# [[{'x1': 0, 'y1': 99, 'x2': 500, 'y2': 400},
#   array([0.9950895], dtype=float32)]]

# %%
# @app.route('/',methods=['POST'])
# def pred():
#     img=request.files['imagefile']
#     img_path="images/"+img.filename
#     img.save(img_path)
#     image=load_img(img_path,target_size=(224,224))
#     image=img_to_array(image)
#     image=image.reshape((1,image.shape[0],image.shape[1],image.shape[2]))
#     image=preprocess_input(image)
#     y=model.predict(image)
#     label=decode_predictions(y)
#     label=label[0][0]
#     classification='%s (%.2f%%)' % (label[1],label[2]*100)
#     return render_template('index.html', prediction=classification)

# %%
if __name__ == '__main__':
    from werkzeug.serving import run_simple
  #  app.run(port=3000, debug=True)
    run_simple('localhost',9000,app)
# Out:
#  * Running on http://localhost:9000/ (Press CTRL+C to quit)
# 127.0.0.1 - - [29/May/2023 18:39:36] "GET / HTTP/1.1" 200 -
# 127.0.0.1 - - [29/May/2023 18:39:36] "GET /favicon.ico HTTP/1.1" 404 -
# 1/1 [==============================] - 14s 14s/step
# [2023-05-29 18:40:29,349] ERROR in app: Exception on / [POST]
# Traceback (most recent call last):
#   File "E:\ProgramFiles\anaconda3\lib\site-packages\flask\app.py", line 2447, in wsgi_app
#     response = self.full_dispatch_request()
#   File "E:\ProgramFiles\anaconda3\lib\site-packages\flask\app.py", line 1952, in full_dispatch_request
#     rv = self.handle_user_exception(e)
#   File "E:\ProgramFiles\anaconda3\lib\site-packages\flask\app.py", line 1821, in handle_user_exception
#     reraise(exc_type, exc_value, tb)
#   File "E:\ProgramFiles\anaconda3\lib\site-packages\flask\_compat.py", line 39, in reraise
#     raise value
#   File "E:\ProgramFiles\anaconda3\lib\site-packages\flask\app.py", line 1950, in full_dispatch_request
#     rv = self.dispatch_request()
#   File "E:\ProgramFiles\anaconda3\lib\site-packages\flask\app.py", line 1936, in dispatch_request
#     return self.view_functions[rule.endpoint](**req.view_args)
#   File "C:\Users\Anil\AppData\Local\Temp\ipykernel_3460\591843747.py", line 26, in pred
#     x=np.argmax(np.array(car)[:,1])
# IndexError: too many indices for array: array is 1-dimensional, but 2 were indexed
# 127.0.0.1 - - [29/May/2023 18:40:29] "POST / HTTP/1.1" 500 -
# 127.0.0.1 - - [29/May/2023 18:47:30] "GET / HTTP/1.1" 200 -
# 1/1 [==============================] - 9s 9s/step
# C:\Users\Anil\AppData\Local\Temp\ipykernel_3460\591843747.py:26: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   x=np.argmax(np.array(car)[:,1])
# C:\Users\Anil\AppData\Local\Temp\ipykernel_3460\591843747.py:36: VisibleDeprecationWarning: Creating an ndarray from ragged nested sequences (which is a list-or-tuple of lists-or-tuples-or ndarrays with different lengths or shapes) is deprecated. If you meant to do this, you must specify 'dtype=object' when creating the ndarray.
#   classification=car[np.argmax(np.array(car)[:,1])][1][0]*100
# 127.0.0.1 - - [29/May/2023 18:48:20] "POST / HTTP/1.1" 200 -
# 127.0.0.1 - - [29/May/2023 18:48:20] "GET /images/images.png HTTP/1.1" 404 -

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [10], in <cell line: 1>()
# ----> 1 python --version
#
# NameError: name 'python' is not defined

# %%
import sys
print(sys.executable)
# Out:
# E:\ProgramFiles\anaconda3\python.exe

# %%
print(sys.version)
# Out:
# 3.9.12 (main, Apr  4 2022, 05:22:27) [MSC v.1916 64 bit (AMD64)]
